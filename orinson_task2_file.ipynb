# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Load Datasets

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Mhdthouyib123/code/refs/heads/main/random_weight_height_dataset%201.csv')
df
# Out:
#      Weight  Height
# 0       116  205.04
# 1        90  186.16
# 2       102  197.84
# 3        91  190.14
# 4        43  155.77
# ..      ...     ...
# 295      49  154.85
# 296      58  164.09
# 297      97  189.70
# 298      40  150.84
# 299     108  199.97
#
# [300 rows x 2 columns]

# %%
df.head()
# Out:
#    Weight  Height
# 0     116  205.04
# 1      90  186.16
# 2     102  197.84
# 3      91  190.14
# 4      43  155.77

# %% [markdown]
# ## Plotting a scatter plot to visualize the relationship between weight and height

# %%
plt.figure(figsize=(6,6))
plt.scatter(df['Weight'] , df['Height'])
plt.xlabel('Weight of the person')
plt.ylabel('Height of the person')
# Out:
# Text(0, 0.5, 'Height of the person')

# %%
df.corr()
# Out:
#           Weight    Height
# Weight  1.000000  0.984925
# Height  0.984925  1.000000

# %% [markdown]
# ## Create pairwise plots for exploring relationships between variables

# %%
import seaborn as sns
sns.pairplot(df)

# %%
x = df[['Weight']]
x
# Out:
#      Weight
# 0       116
# 1        90
# 2       102
# 3        91
# 4        43
# ..      ...
# 295      49
# 296      58
# 297      97
# 298      40
# 299     108
#
# [300 rows x 1 columns]

# %%
y = df['Height']
y
# Out:
# 0      205.04
# 1      186.16
# 2      197.84
# 3      190.14
# 4      155.77
#         ...
# 295    154.85
# 296    164.09
# 297    189.70
# 298    150.84
# 299    199.97
# Name: Height, Length: 300, dtype: float64

# %% [markdown]
# ## Data Splitting

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train ,y_test = train_test_split(x , y , test_size=0.2 , random_state=100)

# %%
x_train
# Out:
#      Weight
# 118      63
# 289      72
# 59       40
# 69      114
# 161     108
# ..      ...
# 66       71
# 53       95
# 79       98
# 280     117
# 8        68
#
# [240 rows x 1 columns]

# %%
x_test
# Out:
#      Weight
# 222     102
# 139      87
# 216      55
# 201      78
# 249      52
# 134      72
# 128     105
# 88       58
# 27      101
# 288      78
# 159      67
# 7        82
# 206      63
# 197      72
# 162     100
# 18      101
# 282      86
# 218     115
# 60       58
# 297      97
# 200      87
# 171      69
# 149      61
# 156      66
# 210      96
# 166      74
# 199      82
# 198      48
# 112      48
# 169      56
# 231      88
# 168      88
# 15      105
# 221      71
# 230      97
# 142      46
# 261      40
# 110      76
# 46      101
# 179     102
# 75      109
# 191      86
# 56       41
# 124      75
# 111      71
# 286      55
# 195      41
# 10       52
# 125      77
# 248      55
# 64       71
# 278      96
# 1        90
# 23       83
# 233      81
# 103      55
# 177      92
# 19       96
# 213      59
# 41       63

# %%
y_train
# Out:
# 118    170.88
# 289    175.81
# 59     151.77
# 69     197.93
# 161    198.12
#         ...
# 66     168.83
# 53     184.50
# 79     193.97
# 280    206.40
# 8      170.33
# Name: Height, Length: 240, dtype: float64

# %%
y_test
# Out:
# 222    195.38
# 139    181.26
# 216    162.76
# 201    172.48
# 249    156.88
# 134    176.55
# 128    192.67
# 88     159.93
# 27     192.66
# 288    177.24
# 159    164.73
# 7      181.17
# 206    168.95
# 197    175.71
# 162    188.65
# 18     191.47
# 282    185.87
# 218    202.01
# 60     162.43
# 297    189.70
# 200    187.58
# 171    170.99
# 149    162.50
# 156    167.37
# 210    190.37
# 166    178.65
# 199    182.56
# 198    153.68
# 112    154.60
# 169    160.13
# 231    180.69
# 168    186.10
# 15     192.57
# 221    171.94
# 230    188.37
# 142    153.08
# 261    150.12
# 110    177.01
# 46     195.10
# 179    195.90
# 75     198.76
# 191    184.77
# 56     154.17
# 124    172.03
# 111    169.08
# 286    162.87
# 195    150.68
# 10     161.51
# 125    177.85
# 248    158.95
# 64     172.72
# 278    191.07
# 1      186.16
# 23     178.95
# 233    177.12
# 103    158.04
# 177    188.32
# 19     184.59
# 213    164.67
# 41     166.91
# Name: Height, dtype: float64

# %% [markdown]
# ## Standardization

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
x_train
# Out:
# array([[-0.70242478],
#        [-0.31027241],
#        [-1.70459195],
#        [ 1.51977199],
#        [ 1.25833708],
#        [-1.48672952],
#        [ 0.43045985],
#        [-0.61527981],
#        [-1.00743218],
#        [ 0.16902493],
#        [ 1.25833708],
#        [-1.61744698],
#        [-1.39958455],
#        [-0.00526501],
#        [-0.83314224],
#        [-0.70242478],
#        [-1.70459195],
#        [ 0.95332968],
#        [ 0.77903973],
#        [ 1.60691696],
#        [ 1.04047465],
#        [-0.17955495],
#        [-1.61744698],
#        [ 1.51977199],
#        [-0.26669992],
#        [ 0.77903973],
#        [-0.57170732],
#        [-0.65885229],
#        [ 1.30190956],
#        [ 0.51760482],
#        [ 0.95332968],
#        [ 0.73546725],
#        [-0.61527981],
#        [ 0.77903973],
#        [ 0.90975719],
#        [ 0.77903973],
#        [-1.26886709],
#        [-0.31027241],
#        [-1.53030201],
#        [ 1.1711921 ],
#        [-0.31027241],
# ...

# %%
x_test
# Out:
# array([[ 0.99690216],
#        [ 0.34331488],
#        [-1.05100466],
#        [-0.04883749],
#        [-1.18172212],
#        [-0.31027241],
#        [ 1.12761962],
#        [-0.92028721],
#        [ 0.95332968],
#        [-0.04883749],
#        [-0.52813484],
#        [ 0.12545245],
#        [-0.70242478],
#        [-0.31027241],
#        [ 0.90975719],
#        [ 0.95332968],
#        [ 0.29974239],
#        [ 1.56334448],
#        [-0.92028721],
#        [ 0.77903973],
#        [ 0.34331488],
#        [-0.44098987],
#        [-0.78956975],
#        [-0.57170732],
#        [ 0.73546725],
#        [-0.22312744],
#        [ 0.12545245],
#        [-1.35601206],
#        [-1.35601206],
#        [-1.00743218],
#        [ 0.38688736],
#        [ 0.38688736],
#        [ 1.12761962],
#        [-0.35384489],
#        [ 0.77903973],
#        [-1.44315704],
#        [-1.70459195],
#        [-0.13598247],
#        [ 0.95332968],
#        [ 0.99690216],
#        [ 1.30190956],
# ...

# %% [markdown]
# # Model Building

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression(n_jobs=-1)
lr.fit(x_train , y_train)
# Out:
# LinearRegression(n_jobs=-1)

# %%
print("coefficient is = " , lr.coef_)
print("intercept is = " , lr.intercept_)
# Out:
# coefficient is =  [16.28764574]
# intercept is =  177.42654166666668

# %%
plt.scatter(x_train , y_train)
plt.plot(x_train , lr.predict(x_train))

# %%
y_pred = lr.predict(x_test)
y_pred
# Out:
# array([193.66373091, 183.01833275, 160.30815002, 176.63109386,
#        158.17907039, 172.3729346 , 195.79281054, 162.43722965,
#        192.9540377 , 176.63109386, 168.82446855, 179.4698667 ,
#        165.98569571, 172.3729346 , 192.24434449, 192.9540377 ,
#        182.30863954, 202.88974264, 162.43722965, 190.11526486,
#        183.01833275, 170.24385497, 164.56630929, 168.11477534,
#        189.40557164, 173.79232102, 179.4698667 , 155.34029755,
#        155.34029755, 161.01784323, 183.72802596, 183.72802596,
#        195.79281054, 171.66324139, 190.11526486, 153.92091113,
#        149.66275187, 175.21170744, 192.9540377 , 193.66373091,
#        198.63158338, 182.30863954, 150.37244508, 174.50201423,
#        171.66324139, 160.30815002, 150.37244508, 158.17907039,
#        175.92140065, 160.30815002, 171.66324139, 189.40557164,
#        185.14741238, 180.17955991, 178.76017349, 160.30815002,
#        186.5667988 , 189.40557164, 163.14692287, 165.98569571])

# %%
from sklearn.metrics import mean_absolute_error , mean_squared_error
mse = mean_squared_error(y_test , y_pred)
mae = mean_absolute_error(y_test , y_pred)
rmse = np.sqrt(mse)

# %%
print("MSE =" , mse)
print("MAE =" , mae)
print("RMSE = " , rmse)
# Out:
# MSE = 5.66690459043932
# MAE = 2.0232532284692324
# RMSE =  2.3805261163111235

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test  , y_pred)
score
# Out:
# 0.9703827232183625

# %%
import statsmodels.api as sm
model = sm.OLS(y_train , x_train).fit()
prediction = model.predict(x_train)
prediction
# Out:
# array([-11.44084596,  -5.05360707, -27.7637898 ,  24.75350776,
#         20.4953485 , -24.21532375,   7.01117751, -10.02145954,
#        -16.40869843,   2.75301824,  20.4953485 , -26.34440338,
#        -22.79593732,  -0.0857546 , -13.56992559, -11.44084596,
#        -27.7637898 ,  15.52749603,  12.68872319,  26.17289418,
#         16.94688245,  -2.92452744, -26.34440338,  24.75350776,
#         -4.34391386,  12.68872319,  -9.31176633, -10.73115275,
#         21.20504171,   8.43056393,  15.52749603,  11.97902998,
#        -10.02145954,  12.68872319,  14.81780282,  12.68872319,
#        -20.66685769,  -5.05360707, -24.92501696,  19.07596208,
#         -5.05360707,  14.10810961,   9.14025714,  12.68872319,
#        -12.15053917,  21.20504171,  15.52749603, -27.05409659,
#         -5.05360707,  -7.89237991, -14.2796188 , -10.73115275,
#         29.01166702,  22.62442813, -14.98931201, -14.98931201,
#          5.59179109,  27.5922806 ,  21.20504171, -10.73115275,
# ...

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                 Height   R-squared (uncentered):                   0.008
# Model:                            OLS   Adj. R-squared (uncentered):              0.004
# Method:                 Least Squares   F-statistic:                              2.014
# Date:                Mon, 06 Jan 2025   Prob (F-statistic):                       0.157
# Time:                        16:09:24   Log-Likelihood:                         -1583.4
# No. Observations:                 240   AIC:                                      3169.
# Df Residuals:                     239   BIC:                                      3172.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
lr.predict(scaler.transform([[78]]))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([176.63109386])
